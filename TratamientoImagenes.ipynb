# %% [markdown]
# <a href="https://colab.research.google.com/github/HeberthDCM/CUDA/blob/main/TratamientoImagenes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
imagen = cv2.imread('auto.jpg')
imagen
# Out:
# array([[[251, 251, 251],
#         [251, 251, 251],
#         [252, 252, 252],
#         ...,
#         [249, 237, 231],
#         [249, 237, 231],
#         [249, 237, 231]],
#
#        [[251, 251, 251],
#         [251, 251, 251],
#         [252, 252, 252],
#         ...,
#         [249, 237, 231],
#         [249, 237, 231],
#         [249, 237, 231]],
#
#        [[251, 251, 251],
#         [252, 252, 252],
#         [252, 252, 252],
#         ...,
#         [249, 238, 230],
#         [249, 238, 230],
#         [250, 239, 231]],
#
#        ...,
#
#        [[ 19, 102,  57],
#         [ 13,  99,  51],
#         [ 29, 124,  73],
#         ...,
#         [ 31, 136,  93],
#         [ 30, 128,  82],
#         [ 30, 123,  78]],
#
#        [[ 21, 100,  61],
#         [ 31, 115,  73],
#         [ 46, 140,  93],
#         ...,
#         [ 46, 146, 110],
#         [ 36, 137,  92],
#         [ 33, 132,  86]],
#
#        [[ 29, 106,  78],
#         [ 42, 122,  91],
#         [ 47, 134,  98],
# ...

# %%
imagen_escala_grises = cv2.cvtColor(imagen, cv2.COLOR_BGR2GRAY)
imagen_escala_grises
# Out:
# array([[251, 251, 252, ..., 237, 237, 237],
#        [251, 251, 252, ..., 237, 237, 237],
#        [251, 252, 252, ..., 237, 237, 238],
#        ...,
#        [ 79,  75,  98, ..., 111, 103,  99],
#        [ 79,  93, 115, ..., 124, 112, 107],
#        [ 89, 104, 113, ..., 135, 113, 108]], dtype=uint8)

# %%
imagen_RGB = cv2.cvtColor(imagen, cv2.COLOR_BGR2RGB)
imagen_RGB
# Out:
# array([[[251, 251, 251],
#         [251, 251, 251],
#         [252, 252, 252],
#         ...,
#         [231, 237, 249],
#         [231, 237, 249],
#         [231, 237, 249]],
#
#        [[251, 251, 251],
#         [251, 251, 251],
#         [252, 252, 252],
#         ...,
#         [231, 237, 249],
#         [231, 237, 249],
#         [231, 237, 249]],
#
#        [[251, 251, 251],
#         [252, 252, 252],
#         [252, 252, 252],
#         ...,
#         [230, 238, 249],
#         [230, 238, 249],
#         [231, 239, 250]],
#
#        ...,
#
#        [[ 57, 102,  19],
#         [ 51,  99,  13],
#         [ 73, 124,  29],
#         ...,
#         [ 93, 136,  31],
#         [ 82, 128,  30],
#         [ 78, 123,  30]],
#
#        [[ 61, 100,  21],
#         [ 73, 115,  31],
#         [ 93, 140,  46],
#         ...,
#         [110, 146,  46],
#         [ 92, 137,  36],
#         [ 86, 132,  33]],
#
#        [[ 78, 106,  29],
#         [ 91, 122,  42],
#         [ 98, 134,  47],
# ...

# %%
cv2.imwrite('imagen_escala_grises.jpg', imagen_escala_grises)
# Out:
# True
